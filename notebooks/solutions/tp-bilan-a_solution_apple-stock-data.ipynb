# %%
import sqlite3

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.tseries.offsets import BDay
import seaborn as sns
from scipy.stats import zscore
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.tsa.arima.model import ARIMA
import yfinance

# %%
CLOSE = "Close"

# %% [markdown]
# Récupérer l'historique de l'action Apple (APPL) grâce à l'API en ligne de Yahoo Finance. En backup, le fichier apple_history.csv est aussi fourni dans le dépôt Github.

# %%
apple = yfinance.Ticker("AAPL")
apple_df = apple.history(start="2010-01-01", end="2025-01-01").sort_index()
print(apple_df.head())
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-01-04 00:00:00-05:00  6.414464  6.446622  6.382907  6.431896  493729600
# 2010-01-05 00:00:00-05:00  6.449629  6.479383  6.409055  6.443017  601904800
# 2010-01-06 00:00:00-05:00  6.443018  6.468564  6.333921  6.340533  552160000
# 2010-01-07 00:00:00-05:00  6.363973  6.371486  6.282826  6.328809  477131200
# 2010-01-08 00:00:00-05:00  6.320394  6.371486  6.283127  6.370885  447610800
#
#                            Dividends  Stock Splits
# Date
# 2010-01-04 00:00:00-05:00        0.0           0.0
# 2010-01-05 00:00:00-05:00        0.0           0.0
# 2010-01-06 00:00:00-05:00        0.0           0.0
# 2010-01-07 00:00:00-05:00        0.0           0.0
# 2010-01-08 00:00:00-05:00        0.0           0.0

# %%
# Alternative : chargement du fichier apple_history.csv

# %% [markdown]
# Explorer ce fichier ? Y a-t-il des valeurs manquantes ?

# %%
apple_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3774 entries, 2010-01-04 00:00:00-05:00 to 2024-12-31 00:00:00-05:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          3774 non-null   float64
#  1   High          3774 non-null   float64
#  2   Low           3774 non-null   float64
#  3   Close         3774 non-null   float64
#  4   Volume        3774 non-null   int64
#  5   Dividends     3774 non-null   float64
#  6   Stock Splits  3774 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 235.9 KB

# %% [markdown]
# Pas de valeurs manquantes.

# %%
apple_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  3774.000000  3774.000000  3774.000000  3774.000000  3.774000e+03
# mean     67.377155    68.086941    66.709768    67.433261  2.299191e+08
# std      65.438023    66.125667    64.819099    65.516757  2.180723e+08
# min       5.781524     5.890621     5.717808     5.771906  2.323470e+07
# 25%      17.442394    17.622335    17.293329    17.438809  8.492275e+07
# 50%      35.308426    35.681949    34.917553    35.277456  1.403920e+08
# 75%     126.173639   127.831547   124.664349   126.743412  3.081386e+08
# max     257.568678   259.474086   257.010028   258.396667  1.880998e+09
#
#          Dividends  Stock Splits
# count  3774.000000   3774.000000
# mean      0.002316      0.002915
# std       0.020785      0.131222
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      0.000000
# 75%       0.000000      0.000000
# max       0.250000      7.000000

# %%
apple_df.head(20)
# Out:
#                                Open      High       Low     Close      Volume  \
# Date
# 2010-01-04 00:00:00-05:00  6.414464  6.446622  6.382907  6.431896   493729600
# 2010-01-05 00:00:00-05:00  6.449629  6.479383  6.409055  6.443017   601904800
# 2010-01-06 00:00:00-05:00  6.443018  6.468564  6.333921  6.340533   552160000
# 2010-01-07 00:00:00-05:00  6.363973  6.371486  6.282826  6.328809   477131200
# 2010-01-08 00:00:00-05:00  6.320394  6.371486  6.283127  6.370885   447610800
# 2010-01-11 00:00:00-05:00  6.395532  6.401542  6.264796  6.314686   462229600
# 2010-01-12 00:00:00-05:00  6.287034  6.304466  6.203784  6.242854   594459600
# 2010-01-13 00:00:00-05:00  6.247364  6.339329  6.134059  6.330914   605892000
# 2010-01-14 00:00:00-05:00  6.314686  6.325205  6.281927  6.294249   432894000
# 2010-01-15 00:00:00-05:00  6.339330  6.359466  6.187255  6.189059   594067600
# 2010-01-19 00:00:00-05:00  6.261188  6.467360  6.228430  6.462852   730007600
# 2010-01-20 00:00:00-05:00  6.458946  6.478181  6.296353  6.363374   612152800
# 2010-01-21 00:00:00-05:00  6.373893  6.410859  6.227528  6.253375   608154400
# 2010-01-22 00:00:00-05:00  6.214605  6.236244  5.925484  5.943216   881767600
# 2010-01-25 00:00:00-05:00  6.086273  6.152091  6.016548  6.103104  1065699600
# 2010-01-26 00:00:00-05:00  6.189660  6.422881  6.088378  6.189360  1867110000
# 2010-01-27 00:00:00-05:00  6.216708  6.328810  5.996711  6.247664  1722568400
# 2010-01-28 00:00:00-05:00  6.159004  6.176135  5.971767  5.989498  1173502400
# 2010-01-29 00:00:00-05:00  6.043295  6.076955  5.717808  5.772206  1245952400
# 2010-02-01 00:00:00-05:00  5.781524  5.890621  5.749366  5.852452   749876400
#
#                            Dividends  Stock Splits
# Date
# 2010-01-04 00:00:00-05:00        0.0           0.0
# 2010-01-05 00:00:00-05:00        0.0           0.0
# 2010-01-06 00:00:00-05:00        0.0           0.0
# 2010-01-07 00:00:00-05:00        0.0           0.0
# 2010-01-08 00:00:00-05:00        0.0           0.0
# 2010-01-11 00:00:00-05:00        0.0           0.0
# 2010-01-12 00:00:00-05:00        0.0           0.0
# 2010-01-13 00:00:00-05:00        0.0           0.0
# 2010-01-14 00:00:00-05:00        0.0           0.0
# 2010-01-15 00:00:00-05:00        0.0           0.0
# 2010-01-19 00:00:00-05:00        0.0           0.0
# 2010-01-20 00:00:00-05:00        0.0           0.0
# 2010-01-21 00:00:00-05:00        0.0           0.0
# 2010-01-22 00:00:00-05:00        0.0           0.0
# 2010-01-25 00:00:00-05:00        0.0           0.0
# 2010-01-26 00:00:00-05:00        0.0           0.0
# 2010-01-27 00:00:00-05:00        0.0           0.0
# 2010-01-28 00:00:00-05:00        0.0           0.0
# 2010-01-29 00:00:00-05:00        0.0           0.0
# 2010-02-01 00:00:00-05:00        0.0           0.0

# %% [markdown]
# Visualiser l'historique des prix de clôture sur un graphe simple.

# %%
plt.figure()
plt.plot(apple_df.index, apple_df[CLOSE])
plt.title("Cours de clôture d'Apple au fil du temps")
plt.xlabel("Date")
plt.ylabel("Cours de clôture")
plt.show()

# %% [markdown]
# Calculer la variation relative du cours de clôture d'une journée à l'autre. Pour cela, chercher dans la documentation ou sur internet une méthode des Series de pandas réalisant directement ce calcul.

# %%
apple_df["pct_change"] = apple_df[CLOSE].pct_change()

# %%
plt.figure()
plt.plot(apple_df.index, apple_df["pct_change"])
plt.title("Variation relative du cours de clôture d'Apple au fil du temps")
plt.xlabel("Date")
plt.ylabel("Variation relative")
plt.show()

# %% [markdown]
# A l'aide de scipy, calculer le z-score associé à cette colonne. Déterminer les journées à variations atypiques à partir de ce score (vous pouvez par exemple par un seuil égal à 5, à 3...).

# %%
apple_df["z_score"] = zscore(
    a=apple_df["pct_change"],
    nan_policy="omit",
)

# %%
thresh = 5
unusual_mask = abs(apple_df["z_score"]) > thresh
unusual_df = apple_df[unusual_mask]
unusual_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-01-24 00:00:00-05:00   13.947698   14.121438   13.652066   13.659648
# 2019-01-03 00:00:00-05:00   34.297226   34.711709   33.825574   33.870834
# 2020-03-02 00:00:00-05:00   68.413729   73.057371   67.308562   72.419960
# 2020-03-12 00:00:00-04:00   62.029918   65.437516   60.105570   60.161312
# 2020-03-13 00:00:00-04:00   64.199059   67.841748   61.305263   67.369141
# 2020-03-16 00:00:00-04:00   58.639285   62.790929   58.166681   58.702301
# 2020-03-24 00:00:00-04:00   57.284492   60.030445   56.785229   59.834133
# 2020-07-31 00:00:00-04:00  100.011343  103.442746   98.008875  103.292076
# 2022-11-10 00:00:00-05:00  139.433843  144.991837  137.716088  144.991837
#
#                                Volume  Dividends  Stock Splits  pct_change  \
# Date
# 2013-01-24 00:00:00-05:00  1460852400        0.0           0.0   -0.123558
# 2019-01-03 00:00:00-05:00   365248800        0.0           0.0   -0.099607
# 2020-03-02 00:00:00-05:00   341397200        0.0           0.0    0.093101
# 2020-03-12 00:00:00-04:00   418474000        0.0           0.0   -0.098755
# 2020-03-13 00:00:00-04:00   370732000        0.0           0.0    0.119808
# 2020-03-16 00:00:00-04:00   322423600        0.0           0.0   -0.128647
# 2020-03-24 00:00:00-04:00   287531200        0.0           0.0    0.100325
# 2020-07-31 00:00:00-04:00   374336800        0.0           0.0    0.104689
# 2022-11-10 00:00:00-05:00   118854000        0.0           0.0    0.088975
#
#                             z_score
# Date
# 2013-01-24 00:00:00-05:00 -7.104527
# 2019-01-03 00:00:00-05:00 -5.739805
# 2020-03-02 00:00:00-05:00  5.240893
# 2020-03-12 00:00:00-04:00 -5.691223
# 2020-03-13 00:00:00-04:00  6.762736
# 2020-03-16 00:00:00-04:00 -7.394518
# 2020-03-24 00:00:00-04:00  5.652578
# 2020-07-31 00:00:00-04:00  5.901195
# 2022-11-10 00:00:00-05:00  5.005799

# %% [markdown]
# Afficher les lignes associées, ainsi que les lignes des journées précédentes.

# %%
display_mask = unusual_mask | unusual_mask.shift(-1)
display_df = apple_df[display_mask]
display_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2013-01-23 00:00:00-05:00   15.427668   15.615052   15.305171   15.585338
# 2013-01-24 00:00:00-05:00   13.947698   14.121438   13.652066   13.659648
# 2019-01-02 00:00:00-05:00   36.896077   37.839383   36.738858   37.617847
# 2019-01-03 00:00:00-05:00   34.297226   34.711709   33.825574   33.870834
# 2020-02-28 00:00:00-05:00   62.349866   67.475806   62.134161   66.251877
# 2020-03-02 00:00:00-05:00   68.413729   73.057371   67.308562   72.419960
# 2020-03-11 00:00:00-04:00   67.228573   68.156813   65.888309   66.753540
# 2020-03-12 00:00:00-04:00   62.029918   65.437516   60.105570   60.161312
# 2020-03-13 00:00:00-04:00   64.199059   67.841748   61.305263   67.369141
# 2020-03-16 00:00:00-04:00   58.639285   62.790929   58.166681   58.702301
# 2020-03-23 00:00:00-04:00   55.277740   55.379531   51.528412   54.378578
# 2020-03-24 00:00:00-04:00   57.284492   60.030445   56.785229   59.834133
# 2020-07-30 00:00:00-04:00   91.556771   93.607837   91.148503   93.503342
# 2020-07-31 00:00:00-04:00  100.011343  103.442746   98.008875  103.292076
# 2022-11-09 00:00:00-05:00  136.728863  136.778227  132.868861  133.145279
# 2022-11-10 00:00:00-05:00  139.433843  144.991837  137.716088  144.991837
#
#                                Volume  Dividends  Stock Splits  pct_change  \
# Date
# 2013-01-23 00:00:00-05:00   861509600        0.0           0.0    0.018305
# 2013-01-24 00:00:00-05:00  1460852400        0.0           0.0   -0.123558
# 2019-01-02 00:00:00-05:00   148158800        0.0           0.0    0.001141
# 2019-01-03 00:00:00-05:00   365248800        0.0           0.0   -0.099607
# 2020-02-28 00:00:00-05:00   426510000        0.0           0.0   -0.000585
# 2020-03-02 00:00:00-05:00   341397200        0.0           0.0    0.093101
# 2020-03-11 00:00:00-04:00   255598800        0.0           0.0   -0.034730
# 2020-03-12 00:00:00-04:00   418474000        0.0           0.0   -0.098755
# 2020-03-13 00:00:00-04:00   370732000        0.0           0.0    0.119808
# 2020-03-16 00:00:00-04:00   322423600        0.0           0.0   -0.128647
# 2020-03-23 00:00:00-04:00   336752800        0.0           0.0   -0.021244
# 2020-03-24 00:00:00-04:00   287531200        0.0           0.0    0.100325
# 2020-07-30 00:00:00-04:00   158130000        0.0           0.0    0.012101
# 2020-07-31 00:00:00-04:00   374336800        0.0           0.0    0.104689
# 2022-11-09 00:00:00-05:00    74917800        0.0           0.0   -0.033190
# 2022-11-10 00:00:00-05:00   118854000        0.0           0.0    0.088975
#
#                             z_score
# Date
# 2013-01-23 00:00:00-05:00  0.978968
# 2013-01-24 00:00:00-05:00 -7.104527
# 2019-01-02 00:00:00-05:00  0.000931
# 2019-01-03 00:00:00-05:00 -5.739805
# 2020-02-28 00:00:00-05:00 -0.097387
# 2020-03-02 00:00:00-05:00  5.240893
# 2020-03-11 00:00:00-04:00 -2.043044
# 2020-03-12 00:00:00-04:00 -5.691223
# 2020-03-13 00:00:00-04:00  6.762736
# 2020-03-16 00:00:00-04:00 -7.394518
# 2020-03-23 00:00:00-04:00 -1.274592
# 2020-03-24 00:00:00-04:00  5.652578
# 2020-07-30 00:00:00-04:00  0.625428
# 2020-07-31 00:00:00-04:00  5.901195
# 2022-11-09 00:00:00-05:00 -1.955276
# 2022-11-10 00:00:00-05:00  5.005799

# %% [markdown]
# Calculer les quartiles Q1 et Q3, l'écart inter-quartile IQR, et repérer les points en dehors de la plage [Q1 - 1,5 IQR; Q3 + 1,5 IQR]. Visualiser les lignes associées.

# %%
Q1 = apple_df["pct_change"].quantile(0.25)
Q3 = apple_df["pct_change"].quantile(0.75)
IQR = Q3 - Q1
k = 1.5
borne_inf = Q1 - k*IQR
borne_sup = Q3 + k*IQR

iqr_outlier_mask = (apple_df["pct_change"] < borne_inf) | (apple_df["pct_change"] > borne_sup)
apple_df[iqr_outlier_mask]
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-01-19 00:00:00-05:00    6.261188    6.467360    6.228430    6.462852
# 2010-01-22 00:00:00-05:00    6.214605    6.236244    5.925484    5.943216
# 2010-01-28 00:00:00-05:00    6.159004    6.176135    5.971767    5.989498
# 2010-01-29 00:00:00-05:00    6.043295    6.076955    5.717808    5.772206
# 2010-02-04 00:00:00-05:00    5.912559    5.961848    5.757480    5.771906
# ...                               ...         ...         ...         ...
# 2024-04-11 00:00:00-04:00  167.329436  174.406704  167.150524  173.989212
# 2024-05-03 00:00:00-04:00  185.529503  185.877408  181.563465  182.279144
# 2024-06-11 00:00:00-04:00  192.748557  206.195678  192.728661  206.185715
# 2024-08-05 00:00:00-04:00  198.163247  212.506173  195.087635  208.295868
# 2024-09-19 00:00:00-04:00  224.201900  229.014983  223.843160  228.068298
#
#                                Volume  Dividends  Stock Splits  pct_change  \
# Date
# 2010-01-19 00:00:00-05:00   730007600        0.0           0.0    0.044238
# 2010-01-22 00:00:00-05:00   881767600        0.0           0.0   -0.049599
# 2010-01-28 00:00:00-05:00  1173502400        0.0           0.0   -0.041322
# 2010-01-29 00:00:00-05:00  1245952400        0.0           0.0   -0.036279
# 2010-02-04 00:00:00-05:00   757652000        0.0           0.0   -0.036039
# ...                               ...        ...           ...         ...
# 2024-04-11 00:00:00-04:00    91070300        0.0           0.0    0.043271
# 2024-05-03 00:00:00-04:00   163224100        0.0           0.0    0.059816
# 2024-06-11 00:00:00-04:00   172373300        0.0           0.0    0.072649
# 2024-08-05 00:00:00-04:00   119548600        0.0           0.0   -0.048167
# 2024-09-19 00:00:00-04:00    66781300        0.0           0.0    0.037066
#
#                             z_score
# Date
# 2010-01-19 00:00:00-05:00  2.456666
# 2010-01-22 00:00:00-05:00 -2.890255
# 2010-01-28 00:00:00-05:00 -2.418643
# 2010-01-29 00:00:00-05:00 -2.131283
# 2010-02-04 00:00:00-05:00 -2.117602
# ...                             ...
# 2024-04-11 00:00:00-04:00  2.401546
# 2024-05-03 00:00:00-04:00  3.344315
# 2024-06-11 00:00:00-04:00  4.075547
# 2024-08-05 00:00:00-04:00 -2.808682
# 2024-09-19 00:00:00-04:00  2.047960
#
# [184 rows x 9 columns]

# %% [markdown]
# Pour le moment, nous n'avons utilisé qu'une seule colonne (celle des prix de clôture). Visualiser la matrice de corrélation des colonnes du dataframe.

# %%
correlation_matrix = apple_df.select_dtypes(include=np.number).corr()

sns.heatmap(correlation_matrix, annot=True)
plt.title("Matrice de corrélation")
plt.show()

# %% [markdown]
# Utilisons certaines de ces colonnes pour réaliser un modèle simple de prédiction. Essayer de réaliser une régression linéaire du cours de clôture à partir de colonnes que vous jugez pertinentes.

# %%
y = apple_df[CLOSE]
X = apple_df.drop(columns=[CLOSE]).fillna(0)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7)

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr_model.coef_
# Out:
# array([-4.57857960e-01,  7.45025988e-01,  7.13050463e-01,  6.55775637e-11,
#         4.47581677e-01, -3.75172178e-03,  4.25140602e-03,  2.42226873e-01])

# %%
y_pred = lr_model.predict(X_test)

# %%
print(mean_squared_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 0.24428624532249152
# 0.9999433014665634

# %% [markdown]
# Est-il possible de faire une prédiction du cours de clôture pour aujourd'hui ? Critiquer la regression linéaire pour cette application.

# %% [markdown]
# Bonus 1 : s'il vous reste du temps, essayer de réaliser une ARIMA sur le cours de clôture.

# %%
mod = ARIMA(apple_df[CLOSE])
res = mod.fit()

# %%
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 3774
# Model:                          ARIMA   Log Likelihood              -21138.597
# Date:                Mon, 21 Jul 2025   AIC                          42281.193
# Time:                        09:38:11   BIC                          42293.665
# Sample:                             0   HQIC                         42285.627
#                                - 3774
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         67.4339      1.756     38.396      0.000      63.992      70.876
# sigma2      4290.3479    180.707     23.742      0.000    3936.169    4644.527
# ===================================================================================
# Ljung-Box (L1) (Q):                3766.19   Jarque-Bera (JB):               666.41
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.12   Skew:                             1.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# A noter que vu l'ordre choisi (0, 0, 0), ce modèle prédira toujours la moyenne de la série.

# %%
forecast_steps = 30
forecast = res.get_forecast(steps=forecast_steps)
forecast_df = forecast.summary_frame()

# %%
forecast_df.head()
# Out:
# Close       mean    mean_se  mean_ci_lower  mean_ci_upper
# 3774   67.433851  65.500747     -60.945254     195.812957
# 3775   67.433851  65.500747     -60.945254     195.812957
# 3776   67.433851  65.500747     -60.945254     195.812957
# 3777   67.433851  65.500747     -60.945254     195.812957
# 3778   67.433851  65.500747     -60.945254     195.812957

# %%
mod = ARIMA(apple_df[CLOSE], order=(5, 0, 1))
res = mod.fit()

# %%
print(res.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 3774
# Model:                 ARIMA(5, 0, 1)   Log Likelihood               -7076.771
# Date:                Mon, 21 Jul 2025   AIC                          14169.541
# Time:                        09:38:14   BIC                          14219.428
# Sample:                             0   HQIC                         14187.277
#                                - 3774
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         67.6446    675.151      0.100      0.920   -1255.627    1390.916
# ar.L1          0.0759      0.033      2.269      0.023       0.010       0.141
# ar.L2          0.8879      0.033     26.545      0.000       0.822       0.953
# ar.L3         -0.0116      0.012     -0.986      0.324      -0.035       0.011
# ar.L4          0.0048      0.010      0.475      0.635      -0.015       0.024
# ar.L5          0.0429      0.010      4.150      0.000       0.023       0.063
# ma.L1          0.9144      0.032     28.147      0.000       0.851       0.978
# sigma2         2.4845      0.024    105.174      0.000       2.438       2.531
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             17045.48
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):             117.46   Skew:                             0.11
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
forecast_steps = 100
forecast = res.get_forecast(steps=forecast_steps)
forecast_df = forecast.summary_frame()

# %%
forecast_df.head()
# Out:
# Close        mean   mean_se  mean_ci_lower  mean_ci_upper
# 3774   249.969493  1.576234     246.880131     253.058854
# 3775   250.174712  2.218312     245.826900     254.522523
# 3776   250.183125  2.687980     244.914780     255.451470
# 3777   250.210798  3.069894     244.193916     256.227680
# 3778   250.142594  3.395032     243.488453     256.796735

# %% [markdown]
# Reconstituer l'index des dates futures (en vue d'un futur graphe).

# %%
last_date = apple_df.index[-1]
future_dates = pd.date_range(start=last_date + BDay(1), periods=forecast_steps, freq=BDay())
forecast_df.index = future_dates

# %% [markdown]
# Réaliser la visualisation.

# %%
apple_recent = apple_df[apple_df.index >= "2024-01-01"]

plt.figure(figsize=(12, 6))
plt.plot(apple_recent.index, apple_recent[CLOSE], label="Historique")
plt.plot(forecast_df.index, forecast_df["mean"], label="Prévision ARIMA", color='red')
plt.fill_between(forecast_df.index, forecast_df["mean_ci_lower"], forecast_df["mean_ci_upper"], color='pink', alpha=0.3)
plt.title("Prévision du cours de clôture avec ARIMA(5,1,0)")
plt.xlabel("Date")
plt.ylabel("Cours de clôture")
plt.legend()
plt.show()

# %% [markdown]
# Sans information contextuelle supplémentaire, la prévision moyen terme reste compliquée.

# %% [markdown]
# Bonus 2 : créer une table dans une base de données sqlite3 avec la date et le cours de clôture. Prévoir un upsert (insert/update) pour le cas où l'export traité n'est pas le premier.

# %% [markdown]
# Créer une base de données locale SQLite (ou s'y connecter si elle existe).

# %%
conn = sqlite3.connect("apple_stock.db")
cursor = conn.cursor()

# %% [markdown]
# Créer une table. Ajouter la date comme clef primaire.

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS apple_close (
    date TEXT PRIMARY KEY,
    close REAL
)
""")

# %% [markdown]
# Réaliser l'upsert de chaque ligne.

# %%
for index, row in apple_df.iterrows():
    cursor.execute("""
    INSERT INTO apple_close (date, close)
    VALUES (?, ?)
    ON CONFLICT(date) DO UPDATE SET
        close=excluded.close
    """, (index.strftime("%Y-%m-%d"), row[CLOSE]))

# %%
conn.commit()
conn.close()

# %% [markdown]
# Vérification : lire les 5 premières lignes de la table.

# %%
conn = sqlite3.connect("apple_stock.db")
query = "SELECT * FROM apple_close ORDER BY date ASC LIMIT 5"
df_head = pd.read_sql_query(query, conn)
print(df_head)
conn.close()
# Out:
#          date     close
# 0  2010-01-04  6.431896
# 1  2010-01-05  6.443017
# 2  2010-01-06  6.340533
# 3  2010-01-07  6.328809
# 4  2010-01-08  6.370885
